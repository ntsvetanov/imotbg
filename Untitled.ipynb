# %%
import pandas as pd

# %%
df = pd.read_csv("data/combined_results.csv")

# %%
df = df.sort_values(by="price")

# %%
df = df[df["price"] >0]

# %%
pd.set_option('display.max_colwidth', None)

# %%
df[['title', 'price',  'property_type',  'neighborhood', "site","details_url"]].head(20)
# Out:
#                                       title   price property_type  \
# 218                         Едностаен, 30m²   65000           NaN
# 387                      Ателие/Таван, 28m²   65000           NaN
# 379                             Гараж, 40m²   70000           NaN
# 505                         Продава 2-СТАЕН   92868      двустаен
# 204                          Двустаен, 55m²   93000           NaN
# 506                         Продава 2-СТАЕН   93000      двустаен
# 383                         Едностаен, 60m²  111740           NaN
# 436                         Продава 2-СТАЕН  120000      двустаен
# 507                         Продава 2-СТАЕН  125000      двустаен
# 1028                        Продава 4-СТАЕН  128800   четиристаен
# 1029                        Продава 4-СТАЕН  128800   четиристаен
# 1425  продава Четиристаен апартамент, 86 м2  129000   четиристаен
# 1335  продава Четиристаен апартамент, 86 м2  129000   четиристаен
# ...
